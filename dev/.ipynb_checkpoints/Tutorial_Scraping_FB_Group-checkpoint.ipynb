# %%
# !pip install facebook-scraper
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import facebook_scraper

# %% [markdown]
# https://stackoverflow.com/questions/62090645/how-to-scrape-a-closed-facebook-group-that-i-have-credentials-for-with-facebook

# %% [markdown]
# ### NYC Housing Groups:
# 1. https://www.facebook.com/groups/GypsyHousingNYC/
# 2. https://www.facebook.com/groups/NewYorkCityhousing/
# 3. https://www.facebook.com/groups/2070694583203864/: NYC Queens
# 4. https://www.facebook.com/groups/2050201058584087/: NYC Brooklyn
# 5. https://www.facebook.com/groups/1416151198490459/: NYU Housing
# 6. https://www.facebook.com/groups/626355231038903/: NYC Manhattan

# %%
group_ids = [
    'GypsyHousingNYC',
    'NewYorkCityhousing',
    '2070694583203864',
    '2050201058584087',
    '1416151198490459',
    '626355231038903'
]

# %%
[i for i in get_posts(group='1416151198490459', pages=2)]
# Out:
# [{'post_id': None,
#   'text': '1 bedroom apartment for $2700 per month\n\nReach out to our chatbot for more information or to schedule a viewing: https://m.me/alpacachat?ref=kYHHU3\n\n____________\n\n🏠 The Place: 1 bedroom, 1.5 bathroom apartment\n📍 Location: Williamsburg, Brooklyn\n💵 Monthly Rent: US$2,700\n📅 Lease Start: Now\n⌛ Lease Length: 12 months\n\n____________\n\nNo Fee Duplex Apartment w/ Shared Roof Deck\nUnit 1F is 1 bedroom, flex 2, 1.5 bathroom apartment that has a contemporary open floor plan, abundance of large windows and great natural light. The apartment sports wall-mounted air & heating units that allows renters to keep temperatures to their liking.\nA sharply designed kitchen includes custom lighting,…',
#   'post_text': '1 bedroom apartment for $2700 per month\n\nReach out to our chatbot for more information or to schedule a viewing: https://m.me/alpacachat?ref=kYHHU3\n\n____________\n\n🏠 The Place: 1 bedroom, 1.5 bathroom apartment\n📍 Location: Williamsburg, Brooklyn\n💵 Monthly Rent: US$2,700\n📅 Lease Start: Now\n⌛ Lease Length: 12 months\n\n____________\n\nNo Fee Duplex Apartment w/ Shared Roof Deck\nUnit 1F is 1 bedroom, flex 2, 1.5 bathroom apartment that has a contemporary open floor plan, abundance of large windows and great natural light. The apartment sports wall-mounted air & heating units that allows renters to keep temperatures to their liking.\nA sharply designed kitchen includes custom lighting,…',
#   'shared_text': '',
#   'time': datetime.datetime(2020, 12, 25, 21, 46, 10),
#   'image': 'https://scontent-lga3-2.xx.fbcdn.net/v/t1.0-9/fr/cp0/e15/q65/133114800_455037272536501_4330286548300774204_o.jpg?_nc_cat=105&ccb=2&_nc_sid=07e735&_nc_ohc=zdm9PcYdIPgAX-jrFXp&_nc_ht=scontent-lga3-2.xx&tp=14&oh=19fc2ab6de6e9bae3aeee3f6090c4d38&oe=600B8108',
#   'video': None,
#   'video_thumbnail': None,
#   'video_id': None,
#   'likes': 0,
#   'comments': 0,
#   'shares': 0,
#   'post_url': None,
#   'link': 'https://m.me/alpacachat?ref=kYHHU3',
#   'user_id': '102134301160135',
#   'images': ['https://scontent-lga3-2.xx.fbcdn.net/v/t1.0-9/fr/cp0/e15/q65/133114800_455037272536501_4330286548300774204_o.jpg?_nc_cat=105&ccb=2&_nc_sid=07e735&_nc_ohc=zdm9PcYdIPgAX-jrFXp&_nc_ht=scontent-lga3-2.xx&tp=14&oh=19fc2ab6de6e9bae3aeee3f6090c4d38&oe=600B8108',
#    'https://scontent-lga3-2.xx.fbcdn.net/v/t1.0-9/fr/cp0/e15/q65/133349387_455037292536499_4642056944471225651_o.jpg?_nc_cat=101&ccb=2&_nc_sid=07e735&_nc_ohc=xxJ0SQyEeiYAX-hy5oI&_nc_ht=scontent-lga3-2.xx&tp=14&oh=bb3543afa65944049a11c602ce9f3a77&oe=600B16EF',
#    'https://scontent-lga3-2.xx.fbcdn.net/v/t1.0-9/fr/cp0/e15/q65/133769943_455037325869829_5760097970274229420_o.jpg?_nc_cat=111&ccb=2&_nc_sid=07e735&_nc_ohc=dqohkYFldr8AX-ojmoM&_nc_ht=scontent-lga3-2.xx&tp=14&oh=a592a561fe8b8e1c90b7dcc813da9880&oe=600AEE15',
#    'https://scontent-lga3-2.xx.fbcdn.net/v/t1.0-9/fr/cp0/e15/q65/133217393_455037349203160_818615461578333526_o.jpg?_nc_cat=107&ccb=2&_nc_sid=07e735&_nc_ohc=kODE7E10uI8AX9zkl8F&_nc_ht=scontent-lga3-2.xx&tp=14&oh=86c2bf18f0a1f57274e0d0cc913df836&oe=600B5C6E']},
#  {'post_id': '3294273500678210',
#   'text': "3 Beds 2 Baths - Apartment\n***FEMALES ONLY****\nGreenpoint\n1 bedroom availble $1,350\nyou will either be joining a lease (replacing my part) that has 8 months left - or signing your own new 12 month lease\n\nI am not the landlord, but would put you in touch with him to discuss the lease requirements. Rent is $1350 a month, utilities not included, one year starting January 1st, security deposit + first month's rent, with last month free.\n\n2 females both work so are not home all day. one friendly cat named smokey - if your allergic he isnt too bad - I am allergic and dont have a problem since he is super clean.\n\nThe apartment is 2 floors, has 3 bedrooms and 2 full bathrooms. The kitchen…",
#   'post_text': "3 Beds 2 Baths - Apartment\n***FEMALES ONLY****\nGreenpoint\n1 bedroom availble $1,350\nyou will either be joining a lease (replacing my part) that has 8 months left - or signing your own new 12 month lease\n\nI am not the landlord, but would put you in touch with him to discuss the lease requirements. Rent is $1350 a month, utilities not included, one year starting January 1st, security deposit + first month's rent, with last month free.\n\n2 females both work so are not home all day. one friendly cat named smokey - if your allergic he isnt too bad - I am allergic and dont have a problem since he is super clean.\n\nThe apartment is 2 floors, has 3 bedrooms and 2 full bathrooms. The kitchen…",
#   'shared_text': '',
#   'time': datetime.datetime(2020, 12, 25, 22, 17, 14),
#   'image': None,
#   'video': None,
#   'video_thumbnail': None,
#   'video_id': None,
#   'likes': 0,
#   'comments': 0,
#   'shares': 0,
#   'post_url': None,
#   'link': None,
#   'user_id': 1534855919,
#   'images': []},
#  {'post_id': '3294255354013358',
#   'text': 'Hey guys I’m a super chill sophomore looking to go back next semester. I’m looking for some roommates preferably around my age to find a place with, I’ve already found a couple apartments but open to new places too. Feel free to message me here or on insta at aadisharma_15.',
#   'post_text': 'Hey guys I’m a super chill sophomore looking to go back next semester. I’m looking for some roommates preferably around my age to find a place with, I’ve already found a couple apartments but open to new places too. Feel free to message me here or on insta at aadisharma_15.',
#   'shared_text': '',
#   'time': datetime.datetime(2020, 12, 25, 22, 4, 41),
#   'image': None,
#   'video': None,
#   'video_thumbnail': None,
#   'video_id': None,
#   'likes': 0,
#   'comments': 0,
#   'shares': 0,
#   'post_url': None,
#   'link': None,
#   'user_id': '100011568063541',
#   'images': []},
#  {'post_id': '3294243207347906',
#   'text': 'Larger room available in a 2 bedroom, 1 bathroom apartment in BedStuy.\n\nHuge walk in closet. Your room is facing south/west, so lovely morning light. Can easily accommodate a queen bed, nightstand, bookshelf, and desk without feeling overcrowded. Option to come partially furnished with mattress, bookshelf, and lamp if needed.\n\nVirtual doorman/intercom system. Laundry in building. Rooftop and backyard access. 1 block from C @ Rockaway, 8 minute walk to L @ Bushwick-Aberdeen. Approximately 30 minutes to Soho & Union Square. Less than 1 block away from the awesome Daily Press cafe. Apartment is located on the 3rd floor. Utilities are split equally and are approximately $100 a month.\n\nYour roommate is a queer woman. Responsible, value cleanliness, and looking for the same in a roommate. Female strongly preferred, queer friendly a must, and pet friendly. This is a non-smoking household due to allergies.\n\nDana Goerke\u200eGypsy Housing NYC\nDecember 23 at 3:51 AM ·\n\nLarger room available in a 2 bedroom, 1 bathroom apartment in BedStuy.\n\nHuge walk in closet. Your room is facing south/west, so lovely morning light. Can easily accommodate a queen bed, nightstand, bookshelf, and desk without feeling overcrowded. Option to come partially furnished with mattress, bookshelf, and lamp if needed.\n\nVirtual doorman/intercom system. Laundry in building. Rooftop and backyard access. 1 block from C @ Rockaway, 8 minute walk to L @ Bushwick-Aberdeen. Approximately 30 minutes to Soho & Union Square. Less than 1 block away from the awesome Daily Press cafe. Apartment is located on the 3rd floor. Utilities are split equally and are approximately $100 a month.\n\nYour roommate is a queer woman. Responsible, value cleanliness, and looking for the same in a roommate. Female strongly preferred, queer friendly a must, and pet friendly. This is a non-smoking household due to allergies.',
#   'post_text': 'Larger room available in a 2 bedroom, 1 bathroom apartment in BedStuy.\n\nHuge walk in closet. Your room is facing south/west, so lovely morning light. Can easily accommodate a queen bed, nightstand, bookshelf, and desk without feeling overcrowded. Option to come partially furnished with mattress, bookshelf, and lamp if needed.\n\nVirtual doorman/intercom system. Laundry in building. Rooftop and backyard access. 1 block from C @ Rockaway, 8 minute walk to L @ Bushwick-Aberdeen. Approximately 30 minutes to Soho & Union Square. Less than 1 block away from the awesome Daily Press cafe. Apartment is located on the 3rd floor. Utilities are split equally and are approximately $100 a month.\n\nYour roommate is a queer woman. Responsible, value cleanliness, and looking for the same in a roommate. Female strongly preferred, queer friendly a must, and pet friendly. This is a non-smoking household due to allergies.',
#   'shared_text': 'Dana Goerke\u200eGypsy Housing NYC\nDecember 23 at 3:51 AM ·\n\nLarger room available in a 2 bedroom, 1 bathroom apartment in BedStuy.\n\nHuge walk in closet. Your room is facing south/west, so lovely morning light. Can easily accommodate a queen bed, nightstand, bookshelf, and desk without feeling overcrowded. Option to come partially furnished with mattress, bookshelf, and lamp if needed.\n\nVirtual doorman/intercom system. Laundry in building. Rooftop and backyard access. 1 block from C @ Rockaway, 8 minute walk to L @ Bushwick-Aberdeen. Approximately 30 minutes to Soho & Union Square. Less than 1 block away from the awesome Daily Press cafe. Apartment is located on the 3rd floor. Utilities are split equally and are approximately $100 a month.\n\nYour roommate is a queer woman. Responsible, value cleanliness, and looking for the same in a roommate. Female strongly preferred, queer friendly a must, and pet friendly. This is a non-smoking household due to allergies.',
#   'time': datetime.datetime(2020, 12, 25, 21, 56, 21),
#   'image': None,
#   'video': None,
#   'video_thumbnail': None,
#   'video_id': None,
#   'likes': 0,
#   'comments': 0,
#   'shares': 0,
#   'post_url': None,
#   'link': None,
#   'user_id': 26107073,
#   'images': []},
#  {'post_id': None,
#   'text': 'Larger room available in a 2 bedroom, 1 bathroom apartment in BedStuy.\n\nHuge walk in closet. Your room is facing south/west, so lovely morning light. Can easily accommodate a queen bed, nightstand, bookshelf, and desk without feeling overcrowded. Option to come partially furnished with mattress, bookshelf, and lamp if needed.\n\nVirtual doorman/intercom system. Laundry in building. Rooftop and backyard access. 1 block from C @ Rockaway, 8 minute walk to L @ Bushwick-Aberdeen. Approximately 30 minutes to Soho & Union Square. Less than 1 block away from the awesome Daily Press cafe. Apartment is located on the 3rd floor. Utilities are split equally and are approximately $100 a month.\n\nYour roommate is a queer woman. Responsible, value cleanliness, and looking for the same in a roommate. Female strongly preferred, queer friendly a must, and pet friendly. This is a non-smoking household due to allergies.',
#   'post_text': 'Larger room available in a 2 bedroom, 1 bathroom apartment in BedStuy.\n\nHuge walk in closet. Your room is facing south/west, so lovely morning light. Can easily accommodate a queen bed, nightstand, bookshelf, and desk without feeling overcrowded. Option to come partially furnished with mattress, bookshelf, and lamp if needed.\n\nVirtual doorman/intercom system. Laundry in building. Rooftop and backyard access. 1 block from C @ Rockaway, 8 minute walk to L @ Bushwick-Aberdeen. Approximately 30 minutes to Soho & Union Square. Less than 1 block away from the awesome Daily Press cafe. Apartment is located on the 3rd floor. Utilities are split equally and are approximately $100 a month.\n\nYour roommate is a queer woman. Responsible, value cleanliness, and looking for the same in a roommate. Female strongly preferred, queer friendly a must, and pet friendly. This is a non-smoking household due to allergies.',
#   'shared_text': '',
#   'time': datetime.datetime(2020, 12, 23, 3, 51),
#   'image': None,
#   'video': None,
#   'video_thumbnail': None,
#   'video_id': None,
#   'likes': 0,
#   'comments': 0,
#   'shares': 0,
#   'post_url': None,
#   'link': None,
#   'user_id': None,
#   'images': []},
#  {'post_id': None,
#   'text': '1 bedroom apartment for $2700 per month\n\nReach out to our chatbot for more information or to schedule a viewing: https://m.me/alpacachat?ref=kYHHU3\n\n____________\n\n🏠 The Place: 1 bedroom, 1.5 bathroom apartment\n📍 Location: Williamsburg, Brooklyn\n💵 Monthly Rent: US$2,700\n📅 Lease Start: Now\n⌛ Lease Length: 12 months\n\n____________\n\nNo Fee Duplex Apartment w/ Shared Roof Deck\nUnit 1F is 1 bedroom, flex 2, 1.5 bathroom apartment that has a contemporary open floor plan, abundance of large windows and great natural light. The apartment sports wall-mounted air & heating units that allows renters to keep temperatures to their liking.\nA sharply designed kitchen includes custom lighting,…',
#   'post_text': '1 bedroom apartment for $2700 per month\n\nReach out to our chatbot for more information or to schedule a viewing: https://m.me/alpacachat?ref=kYHHU3\n\n____________\n\n🏠 The Place: 1 bedroom, 1.5 bathroom apartment\n📍 Location: Williamsburg, Brooklyn\n💵 Monthly Rent: US$2,700\n📅 Lease Start: Now\n⌛ Lease Length: 12 months\n\n____________\n\nNo Fee Duplex Apartment w/ Shared Roof Deck\nUnit 1F is 1 bedroom, flex 2, 1.5 bathroom apartment that has a contemporary open floor plan, abundance of large windows and great natural light. The apartment sports wall-mounted air & heating units that allows renters to keep temperatures to their liking.\nA sharply designed kitchen includes custom lighting,…',
#   'shared_text': '',
#   'time': datetime.datetime(2020, 12, 25, 21, 46, 10),
#   'image': 'https://scontent-lga3-2.xx.fbcdn.net/v/t1.0-9/fr/cp0/e15/q65/133114800_455037272536501_4330286548300774204_o.jpg?_nc_cat=105&ccb=2&_nc_sid=07e735&_nc_ohc=zdm9PcYdIPgAX-jrFXp&_nc_ht=scontent-lga3-2.xx&tp=14&oh=19fc2ab6de6e9bae3aeee3f6090c4d38&oe=600B8108',
#   'video': None,
#   'video_thumbnail': None,
#   'video_id': None,
#   'likes': 0,
#   'comments': 0,
#   'shares': 0,
#   'post_url': None,
#   'link': 'https://m.me/alpacachat?ref=kYHHU3',
#   'user_id': '102134301160135',
#   'images': ['https://scontent-lga3-2.xx.fbcdn.net/v/t1.0-9/fr/cp0/e15/q65/133114800_455037272536501_4330286548300774204_o.jpg?_nc_cat=105&ccb=2&_nc_sid=07e735&_nc_ohc=zdm9PcYdIPgAX-jrFXp&_nc_ht=scontent-lga3-2.xx&tp=14&oh=19fc2ab6de6e9bae3aeee3f6090c4d38&oe=600B8108',
#    'https://scontent-lga3-2.xx.fbcdn.net/v/t1.0-9/fr/cp0/e15/q65/133349387_455037292536499_4642056944471225651_o.jpg?_nc_cat=101&ccb=2&_nc_sid=07e735&_nc_ohc=xxJ0SQyEeiYAX-hy5oI&_nc_ht=scontent-lga3-2.xx&tp=14&oh=bb3543afa65944049a11c602ce9f3a77&oe=600B16EF',
#    'https://scontent-lga3-2.xx.fbcdn.net/v/t1.0-9/fr/cp0/e15/q65/133769943_455037325869829_5760097970274229420_o.jpg?_nc_cat=111&ccb=2&_nc_sid=07e735&_nc_ohc=dqohkYFldr8AX-ojmoM&_nc_ht=scontent-lga3-2.xx&tp=14&oh=a592a561fe8b8e1c90b7dcc813da9880&oe=600AEE15',
#    'https://scontent-lga3-2.xx.fbcdn.net/v/t1.0-9/fr/cp0/e15/q65/133217393_455037349203160_818615461578333526_o.jpg?_nc_cat=107&ccb=2&_nc_sid=07e735&_nc_ohc=kODE7E10uI8AX9zkl8F&_nc_ht=scontent-lga3-2.xx&tp=14&oh=86c2bf18f0a1f57274e0d0cc913df836&oe=600B5C6E']},
#  {'post_id': '3294111430694417',
#   'text': 'Excellent',
#   'post_text': 'Excellent',
#   'shared_text': '',
#   'time': datetime.datetime(2020, 12, 25, 20, 22, 48),
#   'image': None,
#   'video': None,
#   'video_thumbnail': None,
#   'video_id': None,
#   'likes': 0,
#   'comments': 0,
#   'shares': 0,
#   'post_url': None,
#   'link': None,
#   'user_id': '100011022704674',
#   'images': []},
#  {'post_id': '3294108647361362',
#   'text': 'Excellent',
#   'post_text': 'Excellent',
#   'shared_text': '',
#   'time': datetime.datetime(2020, 12, 25, 20, 20, 41),
#   'image': None,
#   'video': None,
#   'video_thumbnail': None,
#   'video_id': None,
#   'likes': 0,
#   'comments': 0,
#   'shares': 0,
#   'post_url': None,
#   'link': None,
#   'user_id': '100011022704674',
#   'images': []},
#  {'post_id': '3294099567362270',
#   'text': "PIX 11 was live.\n13 hrs ·\n\nWATCH THE 1970 WPIX YULE LOG: Merry Christmas! It wouldn't be the holidays without The WPIX Yule Log. So sit back, relax, enjoy, and don’t forget to say hello and let us know where you are watching!",
#   'post_text': '',
#   'shared_text': "PIX 11 was live.\n13 hrs ·\n\nWATCH THE 1970 WPIX YULE LOG: Merry Christmas! It wouldn't be the holidays without The WPIX Yule Log. So sit back, relax, enjoy, and don’t forget to say hello and let us know where you are watching!",
#   'time': datetime.datetime(2020, 12, 25, 20, 14, 26),
#   'image': None,
#   'video': 'https://scontent-lga3-2.xx.fbcdn.net/v/t66.36281-6/10000000_114716087138617_1398288672123359609_n.mp4?_nc_cat=107&ccb=2&_nc_sid=985c63&efg=eyJ2ZW5jb2RlX3RhZyI6Im9lcF9zZCJ9&_nc_ohc=yaPf1Pf6zkYAX8ThZsZ&_nc_ht=scontent-lga3-2.xx&oh=1c3c9066f837477b14f366e621ed0378&oe=600E19BA',
#   'video_thumbnail': 'https://scontent-lga3-2.xx.fbcdn.net/v/t15.13418-10/cp0/e15/q65/p173x172/128407784_214639663466243_2763276124015111250_n.jpg?_nc_cat=109&ccb=2&_nc_sid=ccf8b3&_nc_ohc=cDR8O-7mrYEAX-9Fv1Y&_nc_ht=scontent-lga3-2.xx&oh=f2668775ba4fe113167ae55781abc3df&oe=600B4D0F',
#   'video_id': '674995396518354',
#   'likes': 0,
#   'comments': 0,
#   'shares': 0,
#   'post_url': 'https://facebook.com/story.php?story_fbid=674995396518354&id=76073377041',
#   'link': None,
#   'user_id': '100001423540995',
#   'images': []},
#  {'post_id': '3294071730698387',
#   'text': 'SPACIOUS 2 BDRM APT IN WILLIAMSBURG*\nGYM & LOUNGE IN BUILDING***ASAP MOVE IN\n\nSpacious 2 bed 1 bath apt in luxury Williamsburg building! This apt has two large windows and a spacious living room and kitchen!! Near many shops, groceries and everyday essentials!\n\nCALL/ TEXT TO VIEW TODAY! 2064129852\n\nFeatures:\n-Central Air\n-Virtual Doorman\n-Gym\n-Lounge\n-Laundry\n-Dishwasher\n-Rooftop\n\nMUST HAVE GOOD CREDIT AND INCOME\nGUARANTORS WELCOME',
#   'post_text': 'SPACIOUS 2 BDRM APT IN WILLIAMSBURG*\nGYM & LOUNGE IN BUILDING***ASAP MOVE IN\n\nSpacious 2 bed 1 bath apt in luxury Williamsburg building! This apt has two large windows and a spacious living room and kitchen!! Near many shops, groceries and everyday essentials!\n\nCALL/ TEXT TO VIEW TODAY! 2064129852\n\nFeatures:\n-Central Air\n-Virtual Doorman\n-Gym\n-Lounge\n-Laundry\n-Dishwasher\n-Rooftop\n\nMUST HAVE GOOD CREDIT AND INCOME\nGUARANTORS WELCOME',
#   'shared_text': '',
#   'time': datetime.datetime(2020, 12, 25, 19, 56, 41),
#   'image': None,
#   'video': None,
#   'video_thumbnail': None,
#   'video_id': None,
#   'likes': 0,
#   'comments': 0,
#   'shares': 0,
#   'post_url': None,
#   'link': None,
#   'user_id': '100043635498990',
#   'images': []},
#  {'post_id': '3294071410698419',
#   'text': 'SPACIOUS 2 BDRM APT IN WILLIAMSBURG*\nGYM & LOUNGE IN BUILDING***ASAP MOVE IN\n\nSpacious 2 bed 1 bath apt in luxury Williamsburg building! This apt has two large windows and a spacious living room and kitchen!! Near many shops, groceries and everyday essentials!\n\nCALL/ TEXT TO VIEW TODAY! 2064129852\n\nFeatures:\n-Central Air\n-Virtual Doorman\n-Gym\n-Lounge\n-Laundry\n-Dishwasher\n-Rooftop\n\nMUST HAVE GOOD CREDIT AND INCOME\nGUARANTORS WELCOME',
#   'post_text': 'SPACIOUS 2 BDRM APT IN WILLIAMSBURG*\nGYM & LOUNGE IN BUILDING***ASAP MOVE IN\n\nSpacious 2 bed 1 bath apt in luxury Williamsburg building! This apt has two large windows and a spacious living room and kitchen!! Near many shops, groceries and everyday essentials!\n\nCALL/ TEXT TO VIEW TODAY! 2064129852\n\nFeatures:\n-Central Air\n-Virtual Doorman\n-Gym\n-Lounge\n-Laundry\n-Dishwasher\n-Rooftop\n\nMUST HAVE GOOD CREDIT AND INCOME\nGUARANTORS WELCOME',
#   'shared_text': '',
#   'time': datetime.datetime(2020, 12, 25, 19, 56, 33),
#   'image': None,
#   'video': None,
#   'video_thumbnail': None,
#   'video_id': None,
#   'likes': 0,
#   'comments': 0,
#   'shares': 0,
#   'post_url': None,
#   'link': None,
#   'user_id': '100043635498990',
#   'images': []},
#  {'post_id': '3294068547365372',
#   'text': 'Nuna leaf swing , great condition\nFrom newborn. To toddler. To big kid. They keep on growing. One thing that is constant? Their need for comfort and a space to call their own. A gentle nudge from you sways LEAF™ grow from side-to-side. Just like being rocked in your arms. Down and up they go with an adjustable recline that grows with them. Your child will adore it. No matter how old they are.',
#   'post_text': 'Nuna leaf swing , great condition\nFrom newborn. To toddler. To big kid. They keep on growing. One thing that is constant? Their need for comfort and a space to call their own. A gentle nudge from you sways LEAF™ grow from side-to-side. Just like being rocked in your arms. Down and up they go with an adjustable recline that grows with them. Your child will adore it. No matter how old they are.',
#   'shared_text': '',
#   'time': datetime.datetime(2020, 12, 25, 19, 54, 59),
#   'image': None,
#   'video': None,
#   'video_thumbnail': None,
#   'video_id': None,
#   'likes': 0,
#   'comments': 0,
#   'shares': 0,
#   'post_url': None,
#   'link': None,
#   'user_id': '100006487053695',
#   'images': []},
#  {'post_id': '3294057580699802',
#   'text': '',
#   'post_text': '',
#   'shared_text': '',
#   'time': datetime.datetime(2020, 12, 25, 19, 46, 25),
#   'image': None,
#   'video': None,
#   'video_thumbnail': None,
#   'video_id': None,
#   'likes': 0,
#   'comments': 0,
#   'shares': 0,
#   'post_url': None,
#   'link': None,
#   'user_id': '100052997839872',
#   'images': []},
#  {'post_id': '3294047794034114',
#   'text': '181 Chauncey Street #R3\n\nReach out to our chatbot for more information or to schedule a viewing: https://m.me/alpacachat?ref=0SxknC\n\n____________\n\n🏠 The Place: 2 bedroom, 1 bathroom apartment\n📍 Location: Bedford Stuyvesant, Brooklyn\n💵 Monthly Rent: US$2,200\n📅 Lease Start: Now\n⌛ Lease Length: None month\n\n____________\n\nNO FEE! Super Bright 2 BED!\nBRIGHT 2 BED apartment with only a one and half floor walk up featuring stylish gray & white kitchen equipped with stainless steel appliances and quartz counters. Wide plank gray floors, Washer/Dryer Hookup in unit, Air Conditioning units in every room, and Sleek Modern bathrooms with waterfall shower head. The spacious bedrooms have large double…',
#   'post_text': '181 Chauncey Street #R3\n\nReach out to our chatbot for more information or to schedule a viewing: https://m.me/alpacachat?ref=0SxknC\n\n____________\n\n🏠 The Place: 2 bedroom, 1 bathroom apartment\n📍 Location: Bedford Stuyvesant, Brooklyn\n💵 Monthly Rent: US$2,200\n📅 Lease Start: Now\n⌛ Lease Length: None month\n\n____________\n\nNO FEE! Super Bright 2 BED!\nBRIGHT 2 BED apartment with only a one and half floor walk up featuring stylish gray & white kitchen equipped with stainless steel appliances and quartz counters. Wide plank gray floors, Washer/Dryer Hookup in unit, Air Conditioning units in every room, and Sleek Modern bathrooms with waterfall shower head. The spacious bedrooms have large double…',
#   'shared_text': '',
#   'time': datetime.datetime(2020, 12, 25, 19, 39, 4),
#   'image': 'https://scontent-lga3-2.xx.fbcdn.net/v/t1.0-9/fr/cp0/e15/q65/133656748_454988349208060_2697641328364979621_o.jpg?_nc_cat=106&ccb=2&_nc_sid=07e735&_nc_ohc=Ax0tP9fn59wAX_xQwDJ&_nc_ht=scontent-lga3-2.xx&tp=14&oh=69654e33dceaab8dc7adfc30fe2f132d&oe=600A505B',
#   'video': None,
#   'video_thumbnail': None,
#   'video_id': None,
#   'likes': 0,
#   'comments': 0,
#   'shares': 0,
#   'post_url': None,
#   'link': 'https://m.me/alpacachat?ref=0SxknC',
#   'user_id': '102134301160135',
#   'images': ['https://scontent-lga3-2.xx.fbcdn.net/v/t1.0-9/fr/cp0/e15/q65/133656748_454988349208060_2697641328364979621_o.jpg?_nc_cat=106&ccb=2&_nc_sid=07e735&_nc_ohc=Ax0tP9fn59wAX_xQwDJ&_nc_ht=scontent-lga3-2.xx&tp=14&oh=69654e33dceaab8dc7adfc30fe2f132d&oe=600A505B',
#    'https://scontent-lga3-2.xx.fbcdn.net/v/t1.0-9/fr/cp0/e15/q65/132860091_454988372541391_1560422551293409016_o.jpg?_nc_cat=109&ccb=2&_nc_sid=07e735&_nc_ohc=2LsFr5hMtBQAX9bvjai&_nc_ht=scontent-lga3-2.xx&tp=14&oh=39bc700a95fcfe9924589651d697e7f9&oe=600B6830',
#    'https://scontent-lga3-2.xx.fbcdn.net/v/t1.0-9/fr/cp0/e15/q65/133296026_454988402541388_3390851848787104990_o.jpg?_nc_cat=102&ccb=2&_nc_sid=07e735&_nc_ohc=MN9cmGbPcmoAX_uaQtQ&_nc_ht=scontent-lga3-2.xx&tp=14&oh=199c9b97cc7ba0bcaaf66b102e35cb60&oe=600C577E',
#    'https://scontent-lga3-2.xx.fbcdn.net/v/t1.0-9/fr/cp0/e15/q65/132706837_454988429208052_5196189603917292504_o.jpg?_nc_cat=106&ccb=2&_nc_sid=07e735&_nc_ohc=wy2elv_NbKUAX_6RQKo&_nc_ht=scontent-lga3-2.xx&tp=14&oh=33e589f0fcf6fb2309a7d44565e44a1e&oe=600CF318']},
#  {'post_id': '3294040830701477',
#   'text': 'Jamezrodigues Live is live now.\n3 hrs ·\n\na las primeras 1000 personas que adivinen el número correcto asociado con la vaca.\nObtendrá $ 10,000.\nBUENA SUERTE',
#   'post_text': '',
#   'shared_text': 'Jamezrodigues Live is live now.\n3 hrs ·\n\na las primeras 1000 personas que adivinen el número correcto asociado con la vaca.\nObtendrá $ 10,000.\nBUENA SUERTE',
#   'time': datetime.datetime(2020, 12, 25, 19, 33, 36),
#   'image': None,
#   'video': 'https://video-lga3-2.xx.fbcdn.net/hvideo-prn-frc/_nc_ohc-lznkOKdjogoAX8avyt2/_nc_cat-103/v/r-pLdIOi8Nf6nsxw5-HB_/live-dash/dash-abr5/105453688140390.mpd?_nc_rl=AfA7VUHoUPtCf_Ku2wY&ms=m_CNP&oh=d62f9e0f3832c22a01580c64700d0873&oe=5FE873A0',
#   'video_thumbnail': 'https://scontent-lga3-2.xx.fbcdn.net/v/t15.13418-10/cp0/e15/q65/p173x172/131074046_307874917230869_8791067387776362330_n.jpg?_nc_cat=103&ccb=2&_nc_sid=ccf8b3&_nc_ohc=WOofmeV4VJMAX8p8zEf&_nc_ht=scontent-lga3-2.xx&oh=5fd4090a60541e8d58ab983d717519fd&oe=600A6FF1',
#   'video_id': '127611719086418',
#   'likes': 0,
#   'comments': 0,
#   'shares': 0,
#   'post_url': 'https://facebook.com/story.php?story_fbid=127611719086418&id=105449758140783',
#   'link': None,
#   'user_id': '100012680028941',
#   'images': []},
#  {'post_id': '3294016347370592',
#   'text': '',
#   'post_text': '',
#   'shared_text': '',
#   'time': datetime.datetime(2020, 12, 25, 19, 14, 36),
#   'image': None,
#   'video': None,
#   'video_thumbnail': None,
#   'video_id': None,
#   'likes': 0,
#   'comments': 0,
#   'shares': 0,
#   'post_url': None,
#   'link': None,
#   'user_id': '100006948257007',
#   'images': []},
#  {'post_id': '3294002840705276',
#   'text': 'Excelente tires 4',
#   'post_text': 'Excelente tires 4',
#   'shared_text': '',
#   'time': datetime.datetime(2020, 12, 25, 19, 4, 13),
#   'image': None,
#   'video': None,
#   'video_thumbnail': None,
#   'video_id': None,
#   'likes': 0,
#   'comments': 0,
#   'shares': 0,
#   'post_url': None,
#   'link': None,
#   'user_id': '100011022704674',
#   'images': []},
#  {'post_id': '3293999267372300',
#   'text': 'a rims has a broken nothing of the other world can fix two new tires two other semi used',
#   'post_text': 'a rims has a broken nothing of the other world can fix two new tires two other semi used',
#   'shared_text': '',
#   'time': datetime.datetime(2020, 12, 25, 19, 1, 48),
#   'image': None,
#   'video': None,
#   'video_thumbnail': None,
#   'video_id': None,
#   'likes': 0,
#   'comments': 0,
#   'shares': 0,
#   'post_url': None,
#   'link': None,
#   'user_id': '100011022704674',
#   'images': []},
#  {'post_id': '3293967397375487',
#   'text': 'Please share this post because this year we all need some best wishes more than ever!\n\nAl-Maktoum Goods\n11 hrs ·',
#   'post_text': 'Please share this post because this year we all need some best wishes more than ever!',
#   'shared_text': 'Al-Maktoum Goods\n11 hrs ·',
#   'time': datetime.datetime(2020, 12, 25, 18, 36, 39),
#   'image': None,
#   'video': None,
#   'video_thumbnail': None,
#   'video_id': None,
#   'likes': 0,
#   'comments': 0,
#   'shares': 0,
#   'post_url': 'https://facebook.com/story.php?story_fbid=242424437321352&id=100449668185497',
#   'link': None,
#   'user_id': '100043956520714',
#   'images': []},
#  {'post_id': None,
#   'text': '',
#   'post_text': '',
#   'shared_text': '',
#   'time': datetime.datetime(2020, 12, 25, 11, 34, 5, 573823),
#   'image': None,
#   'video': None,
#   'video_thumbnail': None,
#   'video_id': None,
#   'likes': 0,
#   'comments': 0,
#   'shares': 0,
#   'post_url': 'https://facebook.com/story.php?story_fbid=242424437321352&id=100449668185497',
#   'link': None,
#   'user_id': None,
#   'images': []},
#  {'post_id': '3293906567381570',
#   'text': 'Hi there!\n\nI have a semi-furnished room available for sublease in a spacious 2BR/1BA apartment in Bushwick. It’s $1,485 per month + utilities (wifi, electric and gas). Looking for someone to sublet the room for at least 3 months. I would prefer long term.\n\nAvailable on February 1st.\n\nFirst month and deposit required.\n\nAbout the apartment:\n\nThe apartment is on the 2nd floor of a new building. It has virtual concierge, stainless steel appliances, hardwood floors, roof access, washer/dryer IN UNIT and a HUGE PRIVATE ROOF TERRACE. This a 2 bedroom apartment with tons of natural light. We have WiFi, CENTRAL AC/heating system and air purifier.\n\nAbout the room:\n\nThe bedroom is quite large. There is a…',
#   'post_text': 'Hi there!\n\nI have a semi-furnished room available for sublease in a spacious 2BR/1BA apartment in Bushwick. It’s $1,485 per month + utilities (wifi, electric and gas). Looking for someone to sublet the room for at least 3 months. I would prefer long term.\n\nAvailable on February 1st.\n\nFirst month and deposit required.\n\nAbout the apartment:\n\nThe apartment is on the 2nd floor of a new building. It has virtual concierge, stainless steel appliances, hardwood floors, roof access, washer/dryer IN UNIT and a HUGE PRIVATE ROOF TERRACE. This a 2 bedroom apartment with tons of natural light. We have WiFi, CENTRAL AC/heating system and air purifier.\n\nAbout the room:\n\nThe bedroom is quite large. There is a…',
#   'shared_text': '',
#   'time': datetime.datetime(2020, 12, 25, 17, 50, 57),
#   'image': None,
#   'video': None,
#   'video_thumbnail': None,
#   'video_id': None,
#   'likes': 0,
#   'comments': 0,
#   'shares': 0,
#   'post_url': None,
#   'link': None,
#   'user_id': 564310335,
#   'images': []},
#  {'post_id': '3293865204052373',
#   'text': 'St Nicholas Avenue Co-living by AYA Apt 1R Room 3 (29)\n\nReach out to our chatbot for more information or to schedule a viewing: https://m.me/alpacachat?ref=gcy8YI\n\n____________\n\n🏠 The Place: Shared apartment\n📍 Location: Bushwick, Brooklyn\n💵 Monthly Rent: US$1,050\n📅 Lease Start: Now\n⌛ Lease Length: 1 month\n\n____________\n\nThe apartment building is located in Bushwick. Bushwhick is an emerging cultural center of Brooklyn with both Michelin-starred restaurants and $3 street tacos. Bushwick has the best lofts in Brooklyn and has quickly become home to artists, musicians and all sorts of creative types. And yes, there are a ton of warehouse parties. Very close less than a 5 minute walk to the…',
#   'post_text': 'St Nicholas Avenue Co-living by AYA Apt 1R Room 3 (29)\n\nReach out to our chatbot for more information or to schedule a viewing: https://m.me/alpacachat?ref=gcy8YI\n\n____________\n\n🏠 The Place: Shared apartment\n📍 Location: Bushwick, Brooklyn\n💵 Monthly Rent: US$1,050\n📅 Lease Start: Now\n⌛ Lease Length: 1 month\n\n____________\n\nThe apartment building is located in Bushwick. Bushwhick is an emerging cultural center of Brooklyn with both Michelin-starred restaurants and $3 street tacos. Bushwick has the best lofts in Brooklyn and has quickly become home to artists, musicians and all sorts of creative types. And yes, there are a ton of warehouse parties. Very close less than a 5 minute walk to the…',
#   'shared_text': '',
#   'time': datetime.datetime(2020, 12, 25, 17, 19, 12),
#   'image': 'https://scontent-lga3-2.xx.fbcdn.net/v/t1.0-9/fr/cp0/e15/q65/132349077_454932832546945_7966021282700659021_o.jpg?_nc_cat=102&ccb=2&_nc_sid=07e735&_nc_ohc=FLF5okNxB4wAX-XxNoN&_nc_ht=scontent-lga3-2.xx&tp=14&oh=11f879bd9e6f2cf4562b7305320bb6fc&oe=600C6903',
#   'video': None,
#   'video_thumbnail': None,
#   'video_id': None,
#   'likes': 0,
#   'comments': 0,
#   'shares': 0,
#   'post_url': None,
#   'link': 'https://m.me/alpacachat?ref=gcy8YI',
#   'user_id': '102134301160135',
#   'images': ['https://scontent-lga3-2.xx.fbcdn.net/v/t1.0-9/fr/cp0/e15/q65/132349077_454932832546945_7966021282700659021_o.jpg?_nc_cat=102&ccb=2&_nc_sid=07e735&_nc_ohc=FLF5okNxB4wAX-XxNoN&_nc_ht=scontent-lga3-2.xx&tp=14&oh=11f879bd9e6f2cf4562b7305320bb6fc&oe=600C6903',
#    'https://scontent-lga3-2.xx.fbcdn.net/v/t1.0-9/fr/cp0/e15/q65/132026299_454932969213598_4041777860724816564_o.jpg?_nc_cat=111&ccb=2&_nc_sid=07e735&_nc_ohc=U81Z6kcmTEQAX9Ms0cm&_nc_ht=scontent-lga3-2.xx&tp=14&oh=45c732b46d8338b29986bc157f613e3c&oe=600CB415',
#    'https://scontent-lga3-2.xx.fbcdn.net/v/t1.0-9/fr/cp0/e15/q65/132003641_454933072546921_1735105488861564352_o.jpg?_nc_cat=109&ccb=2&_nc_sid=07e735&_nc_ohc=LO0mTFZGwYIAX8g8dfi&_nc_ht=scontent-lga3-2.xx&tp=14&oh=624162d76293fca9ce3b8f2ccab873e0&oe=600AD3A4',
#    'https://scontent-lga3-2.xx.fbcdn.net/v/t1.0-9/fr/cp0/e15/q65/132157436_454933119213583_2262483442164744679_o.jpg?_nc_cat=109&ccb=2&_nc_sid=07e735&_nc_ohc=1sEZgWi096gAX82Nsn9&_nc_ht=scontent-lga3-2.xx&tp=14&oh=ff806ff70d52ab1f3893e36571602e82&oe=600A8312']},
#  {'post_id': '3293854447386782',
#   'text': '- 1 Bedroom 1 Bath\n- Location: West 72rd between Amsterdam&Columbus Ave (Near 1,2,3)\n- Separate Kitchen (DISHWASHER/stove/fridge/microwave)\n- Marble Tiled Bathroom\n- LOFT - Hardwood Floors - Renovated - Available Immediately\n\nTons of other great deals available for Studios, 1 Bed, 2 Beds, etc, throughout the entirety of Manhattan. Call or text 929-335-8466 to go over your criteria and line up some solid options.\n\nok93',
#   'post_text': '- 1 Bedroom 1 Bath\n- Location: West 72rd between Amsterdam&Columbus Ave (Near 1,2,3)\n- Separate Kitchen (DISHWASHER/stove/fridge/microwave)\n- Marble Tiled Bathroom\n- LOFT - Hardwood Floors - Renovated - Available Immediately\n\nTons of other great deals available for Studios, 1 Bed, 2 Beds, etc, throughout the entirety of Manhattan. Call or text 929-335-8466 to go over your criteria and line up some solid options.\n\nok93',
#   'shared_text': '',
#   'time': datetime.datetime(2020, 12, 25, 17, 10, 50),
#   'image': None,
#   'video': None,
#   'video_thumbnail': None,
#   'video_id': None,
#   'likes': 0,
#   'comments': 0,
#   'shares': 0,
#   'post_url': None,
#   'link': None,
#   'user_id': '100005778281983',
#   'images': []},
#  {'post_id': None,
#   'text': '1 bedroom apartment for $2700 per month\n\nReach out to our chatbot for more information or to schedule a viewing: https://m.me/alpacachat?ref=kYHHU3\n\n____________\n\n🏠 The Place: 1 bedroom, 1.5 bathroom apartment\n📍 Location: Williamsburg, Brooklyn\n💵 Monthly Rent: US$2,700\n📅 Lease Start: Now\n⌛ Lease Length: 12 months\n\n____________\n\nNo Fee Duplex Apartment w/ Shared Roof Deck\nUnit 1F is 1 bedroom, flex 2, 1.5 bathroom apartment that has a contemporary open floor plan, abundance of large windows and great natural light. The apartment sports wall-mounted air & heating units that allows renters to keep temperatures to their liking.\nA sharply designed kitchen includes custom lighting,…',
#   'post_text': '1 bedroom apartment for $2700 per month\n\nReach out to our chatbot for more information or to schedule a viewing: https://m.me/alpacachat?ref=kYHHU3\n\n____________\n\n🏠 The Place: 1 bedroom, 1.5 bathroom apartment\n📍 Location: Williamsburg, Brooklyn\n💵 Monthly Rent: US$2,700\n📅 Lease Start: Now\n⌛ Lease Length: 12 months\n\n____________\n\nNo Fee Duplex Apartment w/ Shared Roof Deck\nUnit 1F is 1 bedroom, flex 2, 1.5 bathroom apartment that has a contemporary open floor plan, abundance of large windows and great natural light. The apartment sports wall-mounted air & heating units that allows renters to keep temperatures to their liking.\nA sharply designed kitchen includes custom lighting,…',
#   'shared_text': '',
#   'time': datetime.datetime(2020, 12, 25, 21, 46, 10),
#   'image': 'https://scontent-lga3-2.xx.fbcdn.net/v/t1.0-9/fr/cp0/e15/q65/133114800_455037272536501_4330286548300774204_o.jpg?_nc_cat=105&ccb=2&_nc_sid=07e735&_nc_ohc=zdm9PcYdIPgAX-jrFXp&_nc_ht=scontent-lga3-2.xx&tp=14&oh=19fc2ab6de6e9bae3aeee3f6090c4d38&oe=600B8108',
#   'video': None,
#   'video_thumbnail': None,
#   'video_id': None,
#   'likes': 0,
#   'comments': 0,
#   'shares': 0,
#   'post_url': None,
#   'link': 'https://m.me/alpacachat?ref=kYHHU3',
#   'user_id': '102134301160135',
#   'images': ['https://scontent-lga3-2.xx.fbcdn.net/v/t1.0-9/fr/cp0/e15/q65/133114800_455037272536501_4330286548300774204_o.jpg?_nc_cat=105&ccb=2&_nc_sid=07e735&_nc_ohc=zdm9PcYdIPgAX-jrFXp&_nc_ht=scontent-lga3-2.xx&tp=14&oh=19fc2ab6de6e9bae3aeee3f6090c4d38&oe=600B8108',
#    'https://scontent-lga3-2.xx.fbcdn.net/v/t1.0-9/fr/cp0/e15/q65/133349387_455037292536499_4642056944471225651_o.jpg?_nc_cat=101&ccb=2&_nc_sid=07e735&_nc_ohc=xxJ0SQyEeiYAX-hy5oI&_nc_ht=scontent-lga3-2.xx&tp=14&oh=bb3543afa65944049a11c602ce9f3a77&oe=600B16EF',
#    'https://scontent-lga3-2.xx.fbcdn.net/v/t1.0-9/fr/cp0/e15/q65/133769943_455037325869829_5760097970274229420_o.jpg?_nc_cat=111&ccb=2&_nc_sid=07e735&_nc_ohc=dqohkYFldr8AX-ojmoM&_nc_ht=scontent-lga3-2.xx&tp=14&oh=a592a561fe8b8e1c90b7dcc813da9880&oe=600AEE15',
#    'https://scontent-lga3-2.xx.fbcdn.net/v/t1.0-9/fr/cp0/e15/q65/133217393_455037349203160_818615461578333526_o.jpg?_nc_cat=107&ccb=2&_nc_sid=07e735&_nc_ohc=kODE7E10uI8AX9zkl8F&_nc_ht=scontent-lga3-2.xx&tp=14&oh=86c2bf18f0a1f57274e0d0cc913df836&oe=600B5C6E']},
#  {'post_id': '3293843197387907',
#   'text': '',
#   'post_text': '',
#   'shared_text': '',
#   'time': datetime.datetime(2020, 12, 25, 17, 2, 33),
#   'image': None,
#   'video': None,
#   'video_thumbnail': None,
#   'video_id': None,
#   'likes': 0,
#   'comments': 0,
#   'shares': 0,
#   'post_url': None,
#   'link': None,
#   'user_id': '100003650822123',
#   'images': []},
#  {'post_id': '3293833847388842',
#   'text': 'I have store in the Bronx if you want to know more about this device please call me my number is next to my name I gave wrannty with all my devices also I donʼt do no shipping or delivery Call me at {3478921868}',
#   'post_text': 'I have store in the Bronx if you want to know more about this device please call me my number is next to my name I gave wrannty with all my devices also I donʼt do no shipping or delivery Call me at {3478921868}',
#   'shared_text': '',
#   'time': datetime.datetime(2020, 12, 25, 16, 55, 55),
#   'image': None,
#   'video': None,
#   'video_thumbnail': None,
#   'video_id': None,
#   'likes': 0,
#   'comments': 0,
#   'shares': 0,
#   'post_url': None,
#   'link': None,
#   'user_id': '100006846093152',
#   'images': []},
#  {'post_id': '3293832754055618',
#   'text': 'I have store in the Bronx if you want to know more about this device please call me my number is next to my name I gave wrannty with all my devices also I donʼt do no shipping or delivery Call me at {3478921868}',
#   'post_text': 'I have store in the Bronx if you want to know more about this device please call me my number is next to my name I gave wrannty with all my devices also I donʼt do no shipping or delivery Call me at {3478921868}',
#   'shared_text': '',
#   'time': datetime.datetime(2020, 12, 25, 16, 55, 5),
#   'image': None,
#   'video': None,
#   'video_thumbnail': None,
#   'video_id': None,
#   'likes': 0,
#   'comments': 0,
#   'shares': 0,
#   'post_url': None,
#   'link': None,
#   'user_id': '100006846093152',
#   'images': []},
#  {'post_id': '3293831164055777',
#   'text': 'I have store in the Bronx if you want to know more about this device please call me my number is next to my name I gave wrannty with all my devices also I donʼt do no shipping or delivery Call me at {3478921868}',
#   'post_text': 'I have store in the Bronx if you want to know more about this device please call me my number is next to my name I gave wrannty with all my devices also I donʼt do no shipping or delivery Call me at {3478921868}',
#   'shared_text': '',
#   'time': datetime.datetime(2020, 12, 25, 16, 53, 51),
#   'image': None,
#   'video': None,
#   'video_thumbnail': None,
#   'video_id': None,
#   'likes': 0,
#   'comments': 0,
#   'shares': 0,
#   'post_url': None,
#   'link': None,
#   'user_id': '100006846093152',
#   'images': []},
#  {'post_id': '3293828374056056',
#   'text': '',
#   'post_text': '',
#   'shared_text': '',
#   'time': datetime.datetime(2020, 12, 25, 16, 52, 4),
#   'image': None,
#   'video': None,
#   'video_thumbnail': None,
#   'video_id': None,
#   'likes': 1,
#   'comments': 0,
#   'shares': 0,
#   'post_url': None,
#   'link': None,
#   'user_id': '100028742732609',
#   'images': []},
#  {'post_id': '3293828037389423',
#   'text': 'I have store in the Bronx if you want to know more about this device please call me my number is next to my name I gave wrannty with all my devices also I donʼt do no shipping or delivery Call me at {3478921868}',
#   'post_text': 'I have store in the Bronx if you want to know more about this device please call me my number is next to my name I gave wrannty with all my devices also I donʼt do no shipping or delivery Call me at {3478921868}',
#   'shared_text': '',
#   'time': datetime.datetime(2020, 12, 25, 16, 51, 43),
#   'image': None,
#   'video': None,
#   'video_thumbnail': None,
#   'video_id': None,
#   'likes': 0,
#   'comments': 0,
#   'shares': 0,
#   'post_url': None,
#   'link': None,
#   'user_id': '100006846093152',
#   'images': []},
#  {'post_id': '3293824897389737',
#   'text': 'I have store in the Bronx if you want to know more about this device please call me my number is next to my name I gave wrannty with all my devices also I donʼt do no shipping or delivery Call me at {3478921868}',
#   'post_text': 'I have store in the Bronx if you want to know more about this device please call me my number is next to my name I gave wrannty with all my devices also I donʼt do no shipping or delivery Call me at {3478921868}',
#   'shared_text': '',
#   'time': datetime.datetime(2020, 12, 25, 16, 49, 12),
#   'image': None,
#   'video': None,
#   'video_thumbnail': None,
#   'video_id': None,
#   'likes': 0,
#   'comments': 0,
#   'shares': 0,
#   'post_url': None,
#   'link': None,
#   'user_id': '100006846093152',
#   'images': []},
#  {'post_id': '3293823194056574',
#   'text': 'I have store in the Bronx if you want to know more about this device please call me my number is next to my name I gave wrannty with all my devices also I donʼt do no shipping or delivery Call me at {3478921868}',
#   'post_text': 'I have store in the Bronx if you want to know more about this device please call me my number is next to my name I gave wrannty with all my devices also I donʼt do no shipping or delivery Call me at {3478921868}',
#   'shared_text': '',
#   'time': datetime.datetime(2020, 12, 25, 16, 47, 49),
#   'image': None,
#   'video': None,
#   'video_thumbnail': None,
#   'video_id': None,
#   'likes': 0,
#   'comments': 0,
#   'shares': 0,
#   'post_url': None,
#   'link': None,
#   'user_id': '100006846093152',
#   'images': []},
#  {'post_id': '3293820397390187',
#   'text': 'I have store in the Bronx if you want to know more about this device please call me my number is next to my name I gave wrannty with all my devices also I donʼt do no shipping or delivery Call me at {3478921868}',
#   'post_text': 'I have store in the Bronx if you want to know more about this device please call me my number is next to my name I gave wrannty with all my devices also I donʼt do no shipping or delivery Call me at {3478921868}',
#   'shared_text': '',
#   'time': datetime.datetime(2020, 12, 25, 16, 45, 41),
#   'image': None,
#   'video': None,
#   'video_thumbnail': None,
#   'video_id': None,
#   'likes': 0,
#   'comments': 0,
#   'shares': 0,
#   'post_url': None,
#   'link': None,
#   'user_id': '100006846093152',
#   'images': []},
#  {'post_id': '3293809997391227',
#   'text': 'I have store in the Bronx if you want to know more about this device please call me my number is next to my name I gave wrannty with all my devices also I donʼt do no shipping or delivery Call me at {3478921868}',
#   'post_text': 'I have store in the Bronx if you want to know more about this device please call me my number is next to my name I gave wrannty with all my devices also I donʼt do no shipping or delivery Call me at {3478921868}',
#   'shared_text': '',
#   'time': datetime.datetime(2020, 12, 25, 16, 38, 10),
#   'image': None,
#   'video': None,
#   'video_thumbnail': None,
#   'video_id': None,
#   'likes': 0,
#   'comments': 0,
#   'shares': 0,
#   'post_url': None,
#   'link': None,
#   'user_id': '100006846093152',
#   'images': []},
#  {'post_id': '3293808750724685',
#   'text': 'I have store in the Bronx if you want to know more about this device please call me my number is next to my name I gave wrannty with all my devices also I donʼt do no shipping or delivery Call me at {3478921868}',
#   'post_text': 'I have store in the Bronx if you want to know more about this device please call me my number is next to my name I gave wrannty with all my devices also I donʼt do no shipping or delivery Call me at {3478921868}',
#   'shared_text': '',
#   'time': datetime.datetime(2020, 12, 25, 16, 37, 16),
#   'image': None,
#   'video': None,
#   'video_thumbnail': None,
#   'video_id': None,
#   'likes': 0,
#   'comments': 0,
#   'shares': 0,
#   'post_url': None,
#   'link': None,
#   'user_id': '100006846093152',
#   'images': []},
#  {'post_id': '3293807897391437',
#   'text': 'I have store in the Bronx if you want to know more about this device please call me my number is next to my name I gave wrannty with all my devices also I donʼt do no shipping or delivery Call me at {3478921868}',
#   'post_text': 'I have store in the Bronx if you want to know more about this device please call me my number is next to my name I gave wrannty with all my devices also I donʼt do no shipping or delivery Call me at {3478921868}',
#   'shared_text': '',
#   'time': datetime.datetime(2020, 12, 25, 16, 36, 43),
#   'image': None,
#   'video': None,
#   'video_thumbnail': None,
#   'video_id': None,
#   'likes': 0,
#   'comments': 0,
#   'shares': 0,
#   'post_url': None,
#   'link': None,
#   'user_id': '100006846093152',
#   'images': []},
#  {'post_id': '3293804890725071',
#   'text': 'I have store in the Bronx if you want to know more about this device please call me my number is next to my name I gave wrannty with all my devices also I donʼt do no shipping or delivery Call me at {3478921868}',
#   'post_text': 'I have store in the Bronx if you want to know more about this device please call me my number is next to my name I gave wrannty with all my devices also I donʼt do no shipping or delivery Call me at {3478921868}',
#   'shared_text': '',
#   'time': datetime.datetime(2020, 12, 25, 16, 34, 47),
#   'image': None,
#   'video': None,
#   'video_thumbnail': None,
#   'video_id': None,
#   'likes': 0,
#   'comments': 0,
#   'shares': 0,
#   'post_url': None,
#   'link': None,
#   'user_id': '100006846093152',
#   'images': []},
#  {'post_id': '3293803284058565',
#   'text': 'I have store in the Bronx if you want to know more about this device please call me my number is next to my name I gave wrannty with all my devices also I donʼt do no shipping or delivery Call me at {3478921868}',
#   'post_text': 'I have store in the Bronx if you want to know more about this device please call me my number is next to my name I gave wrannty with all my devices also I donʼt do no shipping or delivery Call me at {3478921868}',
#   'shared_text': '',
#   'time': datetime.datetime(2020, 12, 25, 16, 33, 27),
#   'image': None,
#   'video': None,
#   'video_thumbnail': None,
#   'video_id': None,
#   'likes': 0,
#   'comments': 0,
#   'shares': 0,
#   'post_url': None,
#   'link': None,
#   'user_id': '100006846093152',
#   'images': []},
#  {'post_id': '3293801207392106',
#   'text': 'I have store in the Bronx if you want to know more about this device please call me my number is next to my name I gave wrannty with all my devices also I donʼt do no shipping or delivery Call me at {3478921868}',
#   'post_text': 'I have store in the Bronx if you want to know more about this device please call me my number is next to my name I gave wrannty with all my devices also I donʼt do no shipping or delivery Call me at {3478921868}',
#   'shared_text': '',
#   'time': datetime.datetime(2020, 12, 25, 16, 32, 18),
#   'image': None,
#   'video': None,
#   'video_thumbnail': None,
#   'video_id': None,
#   'likes': 0,
#   'comments': 0,
#   'shares': 0,
#   'post_url': None,
#   'link': None,
#   'user_id': '100006846093152',
#   'images': []},
#  {'post_id': '3293797567392470',
#   'text': 'I have store in the Bronx if you want to know more about this device please call me my number is next to my name I gave wrannty with all my devices also I donʼt do no shipping or delivery Call me at {3478921868}',
#   'post_text': 'I have store in the Bronx if you want to know more about this device please call me my number is next to my name I gave wrannty with all my devices also I donʼt do no shipping or delivery Call me at {3478921868}',
#   'shared_text': '',
#   'time': datetime.datetime(2020, 12, 25, 16, 29, 51),
#   'image': None,
#   'video': None,
#   'video_thumbnail': None,
#   'video_id': None,
#   'likes': 0,
#   'comments': 0,
#   'shares': 0,
#   'post_url': None,
#   'link': None,
#   'user_id': '100006846093152',
#   'images': []},
#  {'post_id': '3293797447392482',
#   'text': '',
#   'post_text': '',
#   'shared_text': '',
#   'time': datetime.datetime(2020, 12, 25, 16, 29, 48),
#   'image': None,
#   'video': None,
#   'video_thumbnail': None,
#   'video_id': None,
#   'likes': 0,
#   'comments': 0,
#   'shares': 0,
#   'post_url': None,
#   'link': None,
#   'user_id': '100006948257007',
#   'images': []},
#  {'post_id': '3293795124059381',
#   'text': '1231 White Plains Road 10472 bronx new york',
#   'post_text': '1231 White Plains Road 10472 bronx new york',
#   'shared_text': '',
#   'time': datetime.datetime(2020, 12, 25, 16, 28, 19),
#   'image': None,
#   'video': None,
#   'video_thumbnail': None,
#   'video_id': None,
#   'likes': 0,
#   'comments': 0,
#   'shares': 0,
#   'post_url': None,
#   'link': None,
#   'user_id': '100006846093152',
#   'images': []},
#  {'post_id': '3293786520726908',
#   'text': 'MSI gtx 980ti limited edition 6G\nwork for 2k monitor. 1080p with 144hz or more.',
#   'post_text': 'MSI gtx 980ti limited edition 6G\nwork for 2k monitor. 1080p with 144hz or more.',
#   'shared_text': '',
#   'time': datetime.datetime(2020, 12, 25, 16, 22, 17),
#   'image': None,
#   'video': None,
#   'video_thumbnail': None,
#   'video_id': None,
#   'likes': 0,
#   'comments': 0,
#   'shares': 0,
#   'post_url': None,
#   'link': None,
#   'user_id': '100010502072124',
#   'images': []},
#  {'post_id': '3293762200729340',
#   'text': "Open house by appointment December 27, please reach out in advance to schedule a time slot!\n\nRenovated 2 Bedroom in Prime UES\n\nNo Fee – Can Pay Net Price\n\nApartment Details:\nQueen Sized Bedroom's with Closet and Windows\nRenovated Kitchen with Stainless Steel Appliances\nHardwood Floors\nUpdated Bathroom\n\nLocation Details:\nGristedes Grocery Store on 77th & Lex\nWash & Fold Service in Retail space of the building\nLaundromat across 2nd Avenue\nClose to all the restaurants and dining on 2nd Avenue\nCiti Bike Docking Area directly in front of the building",
#   'post_text': "Open house by appointment December 27, please reach out in advance to schedule a time slot!\n\nRenovated 2 Bedroom in Prime UES\n\nNo Fee – Can Pay Net Price\n\nApartment Details:\nQueen Sized Bedroom's with Closet and Windows\nRenovated Kitchen with Stainless Steel Appliances\nHardwood Floors\nUpdated Bathroom\n\nLocation Details:\nGristedes Grocery Store on 77th & Lex\nWash & Fold Service in Retail space of the building\nLaundromat across 2nd Avenue\nClose to all the restaurants and dining on 2nd Avenue\nCiti Bike Docking Area directly in front of the building",
#   'shared_text': '',
#   'time': datetime.datetime(2020, 12, 25, 16, 4, 40),
#   'image': None,
#   'video': None,
#   'video_thumbnail': None,
#   'video_id': None,
#   'likes': 0,
#   'comments': 0,
#   'shares': 0,
#   'post_url': None,
#   'link': None,
#   'user_id': '100000487130270',
#   'images': []}]
